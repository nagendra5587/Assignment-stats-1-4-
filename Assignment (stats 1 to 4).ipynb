# %%
STATISTICS - 1

TASK 1
1.You survey households in your area to find the average rent they are paying. Find the
standard deviation from the following data:
$1550, $1700, $900, $850, $1000, $950.

SOLUTION:
Step 1: Find the mean:
($1550 + $1700 + $900 + $850 + $1000 + $950)/6 = $1158.33

Step 2: Subtract the mean from each value. This gives you the differences:
$1550 – $1158.33 = $391.67
$1700 – $1158.33 = $541.67
$900 – $1158.33 = -$258.33
$850 – $1158.33 = -$308.33
$1000 – $1158.33 = $158.33
$950 – $1158.33 = $208.33

Step 3: Square the differences you found in Step 3:
$391.672 = 153405.3889
$541.672 = 293406.3889
-$258.332 = 66734.3889
-$308.332 = 95067.3889
$158.332 = 25068.3889
$208.332 = 43401.3889

Step 4: Add up all of the squares you found in Step 3 and divide by 5 (which is 6 – 1):
(153405.3889 + 293406.3889 + 66734.3889 + 95067.3889 + 25068.3889 + 43401.3889) / 5 = 135416.66668

Step 5: Find the square root of the number you found in Step 4 (the variance):
√135416.66668 = 367.99
Answer: The standard deviation is 367.99.

# %%
TASK 2.Find the variance for the following set of data representing trees in California (heights in
feet):
3, 21, 98, 203, 17, 9

SOLUTION:
Step 1: Find the mean:
(3 + 21 + 98 + 203 + 17 + 9)/6 = 58.5 feet

Step 2: Subtract the mean from each value. This gives you the differences:
3   – 58.5 = -55.5
21  – 58.5 = -49.5
98  – 58.5 = -41.5
203 – 58.5 = -37.5
17  – 58.5 = 39.5
9   – 58.5 = 144.5

Step 3: Square the differences you found in Step 3:
-55.5 = 3080.25
-49.5 = 2450.25
-41.5 = 1722.25
-37.5 = 1406.25
 39.5 = 1560.25
144.5 = 20880.25

Step 4: Add up all of the squares you found in Step 3 and divide by 5 (which is 6 – 1):
(3080.25 + 2450.25 + 1722.25 + 1406.25 + 1560.25 +  20880.25) / 5 = 31099.5/5 = 6219.9 
Answer: The variance of following data is 6219.9 feet*2

# %%
TASK 3.
In a class on 100 students, 80 students passed in all subjects, 10 failed in one subject, 7 failed in two 
subjects and 3 failed in three subjects. Find the probability distribution of the variable for number of 
subjects a student from the given class has failed in.

SOLUTION:
For a random student,
The probability of failing in 0 subjects,P(x = 0)= 0.8
The probability of failing in 1 subjects,P(x = 1)= 0.1
The probability of failing in 2 subjects,P(x = 2)= 0.07
The probability of failing in 3 subjects,P(x = 3)= 0.03
The probability distribution can be shown as:
x   =  0    1    2     3 
P(x)= 0.8  0.1  0.07  0.03

# %%
STATISTICS - 2

TASK 1.
A test is conducted which is consisting of 20 MCQs (multiple choices questions) with every MCQ 
having its four options out of which only one is correct. Determine the probability that a person 
undertaking that test has answered exactly 5 questions wrong.

SOLUTION:
If he answered 5 wrong questions then he would have been answered 15 questions perfectly
Hence probability of answering 15 correct questions out of 20 which is also equal to answering 
exactly 5 wrong answers.
then p(x)= 15/20 = 0.75
Answer: probability of answered exactly 5 questions wrong is 0.75

# %%
TASK 2.
A die marked A to E is rolled 50 times. Find the probability of getting a “D” exactly 5 times.

SOLUTION:
Here, n = 50, k = 5, n - k = 45
The probability of success = probability of getting a “D”= p = 1/5 = 0.2
The probability of failure = probability of not getting a “D” = 1 - p = 4/5 = 0.8
P(X = k) = (n! / (k! (n-k)!)) p^k * (1 - p) ^(n-k)
P(X = 5) = (50! / (5! (45)!)) (0.2)^5 * (0.8) ^(45)
P(X = 5) = 0.0295
Answer: Probability of getting a “D” exactly 5 times is 0.0295

# %%
TASK 3.
Two balls are drawn at random in succession without replacement from an urn containing 4 red balls 
and 6 black balls.Find the probabilities of all the possible outcomes.

SOLUTION:
Red balls = 4
Blue balls = 6

CASE 1:If both balls are red
first method: probability of both red balls = 4/10*3/9 = 2/15 = 0.133
second method: probability of both red balls = [(4!/(2!*(4-2)!))*(6!/(0!*(6-0)!))]/(10!/(2!*(10-2)!))
                                             = 2/15 = 0.133

CASE 2: If one ball is red and one ball is blue.
probability of one ball is red and one ball is blue ball = [(4!/(1!*(4-1)!))*(6!/(1!*(6-1)!))]/(10!/(2!*(10-2)!))
                                                         = 8/15 = 0.533
    
CASE 3:If both balls are blue
first method: probability of both blue balls = 6/10×5/9= 30/90=1/3 = 0.333
second method: probability of both red balls = [(4!/(0!*(4-0)!))*(6!/(2!*(6-2)!))]/(10!/(2!*(10-2)!))
                                             = 1/3 = 0.333

# %%
STATISTICS - 3

TASK 1.
In one state, 52% of the voters are Republicans, and 48% are Democrats. In a second state, 47% of the voters are 
Republicans, and 53% are Democrats. Suppose a simple random sample of 100 voters are surveyed from each state.
What is the probability that the survey will show a greater percentage of Republican voters in the second state 
than in the first state?

SOLUTION :
Given that:
state	  Republic	 Democrats
1	      0.52	     0.48
2	      0.47	     0.53
P1 = proportion of republican voters of first state(i.e = 0.52)
P2 = proportion of republican voters of second state(i.e = 0.47)
n1 = no. of voters from sample of first state (i.e = 100)
n2 = no. of voters from sample of second state(i.e = 100)
n1P1 = 100*0.52 = 52
n1(1-P1) = 100*(1-0.52)= 48
n2P2 = 100*0.47 = 47
n2(1-P2) = 100*(1-0.47)= 53
each > than 10
now,The mean of the difference in sample proportions:
E(P1-P2)= 0.52 - 0. 47 = .05
The standard deviation of the difference. 
SD = sqrt((SD1)*2/n1 + (SD2)*2/n2)
   = sqrt((P1(1-P1)/n1 + P2(1-P2)/n2))
   = sqrt((0.52(0.48)/100 + 0.47(0.53)/100))
   = 0.07061

We have to require the probability that P1 is less than P2. This is equivalent to finding the probability that 
p1 - p2 is less than zero.
Z(P1-P2) = (Xm - μ(P1-P2))/SD = (0 - 0.05)/0.0706
         = -0.7082
from -ve Z table we find the probability P = 0.2420
Therefore the probability that the survey will show a greater percentage of republican voters in 
the second state than in the first state is 0.2420

# %%
TASK 2.You take the SAT and score 1100. The mean score for the SAT is 1026 and the standard deviation is 209. 
How well did you score on the test compared to the average test taker ?

SOLUTION :
Given that
here Xm value is your SAT score,
sample mean(Xm) = 1100, population mean(μ)= 1026, standard deviation(SD) = 209
now calculating normal probability, by using formula of Z eqaution, 
Z = (Xm - μ)/SD 
  = (1100 - 1026)/209 = 0.354066
from +ve Z table we find the probability  0.6368 that means i will score 63.68%

# %%
STATISTICS - 4

TASK 1.
Is gender independent of education level? A random sample of 395 people were surveyed and each person was asked to 
report the highest education level they obtained. The data that resulted from the survey is summarized in the 
following table:
    
            High-School Bachelor Masters Ph.D. Total
Female      60           54         46    41    201
Male        40           44         53    57    194
Total      100           98         99    98    395

Question: Are gender and education level dependent at 5% level of significance? In other words, given the 
data collected above, is there a relationship between the gender of an individual and the level of education
that they have obtained?


SOLUTION :
Here the given tables are as follows:
    
         HighSchool   Bachelors   Masters   Ph.d.    Total
Female    60           54          46        41       201
Male      40           44          53        57       194
Total    100           98          99        98       395

STEP1:
now applying Chi-Square Test Statistic:
χ2=∑(O−E)*2/E
where O represents the observed frequency. E is the expected frequency under the null hypothesis and computed by:
E=(row total×column total)/sample size

STEP2:
E value for high school column and female row and same for male row is:
E = (201*100)/395 = 50.886
E = (194*100)/395 = 49.114
E value for Bachelors column and female row and same for male row is:
E = (201*98)/395 = 49.868
E = (194*98)/395 = 48.132
E value for masters column and female row and same for male row is:
E = (201*99)/395 = 50.377
E = (194*99)/395 = 48.632
E value for Ph.d. column and female row and same for male row is:
E = (201*98)/395 = 49.868
E = (194*98)/395 = 48.132

STEP3:
Here's the table of expected counts:
  	      High School 	  Bachelors 	Masters 	Ph.d. 	   Total
Female 	   50.886 	      49.868 	    50.377 	    49.868 	   201
Male 	   49.114 	      48.132 	    48.623 	    48.132 	   194
Total 	  100 	          98 	        99 	        98 	       395

STEP4:
So,χ2 = (60−50.886)*2/50.886 + (40-49.114)*2/49.114 + (54-49.868)*2/49.868 + (44-48.132)*2/48.132
+ (46-50.377)*2/50.377 + (53-48.632)*2/48.632 + (41-49.868)*2/49.868 +(57−48.132)*2/48.132 = 8.004

Let r = total no of rows, c = total no of columns
then, Degree of freedom = (r - 1)*(c - 1)= (2-1)*(4-1)= 3
from t-table critical value of χ2 having degree of freedom 3 is 7.815
Since 8.004 > 7.815, therefore we reject the null hypothesis and conclude that the education level 
depends on gender at a 5% level of significance.

# %%
TASK 2.
Using the following data, perform a one-way analysis of variance using α=.05. Write up the results in APA format.
[Group1: 51, 45, 33, 45, 67]
[Group2: 23, 43, 23, 43, 45]
[Group3: 56, 76, 74, 87, 56]

SOLUTION :
STEP1:
Using the following data, perform a oneway analysis of variance using α=.05. Write up the results in APA format.
[Group1: 51, 45, 33, 45, 67] & sample mean(Xm)= (241/5)= 48.5
[Group2: 23, 43, 23, 43, 45] & sample mean(Xm)= (177/5)= 35.4  
[Group3: 56, 76, 74, 87, 56] & sample mean(Xm)= (349/5)= 69.8

STEP2:
[Group1:]
    value  sample mean(Xm)   deviations   sq deviations    
1    51        48.2           2.8            7.84
2    45        48.2          -3.2           10.24
3    33        48.2         -15.2          231.04
4    45        48.2          -3.2           10.24
5    67        48.2          18.8          353.44

Sum of squared deviations from the mean (SS) for the Groups1 = 612.8

[Group2:]
    value  sample mean(Xm)   deviations   sq deviations
1    23        35.4         -12.4          153.76
2    43        35.4           7.6           57.76
3    23        35.4         -12.4          153.76
4    43        35.4           7.6           57.76
5    45        35.4           9.6           92.16

Sum of squared deviations from the mean (SS) for the Groups2 = 515.2

[Group3:]
    value  sample mean(Xm) deviations sq deviations
1    56        69.8         -13.8          190.44
2    76        69.8           6.2           38.44
3    74        69.8           4.2           17.64
4    87        69.8          17.2          295.84
5    56        69.8         -13.8          190.44

Sum of squared deviations from the mean (SS) for the Groups3 = 732.8

STEP3:
Var1 = (612.8/5−1) = 153.2

Var2 = (515.2/5−1) = 128.8

Var3 = (732.8/5−1) = 183.2

STEP4:
the average within-group variance is
MS(error) = (153.2+128.8+183.2)/3 = 155.07
remaining error (or within) terms for the ANOVA table:
df(error) = 15−3 = 12
SS(error) = (155.07)*12 = 1860.8

STEP5:
same steps in calculating the variance of the sample means for group together:
Grand mean (Xm,grand) = (48.2+35.4+69.8)/3 = 51.13
group  sample mean(Xm)    grand mean    deviations       sq deviations
  1        48.2             51.13          -2.93               8.58
  2        35.4             51.13         -15.73             247.43
  3        69.8             51.13          18.67             348.57
    
STEP6:
Sum of squares (SSmeans)= 604.58
Var(means) = (604.58)/(3−1) = 302.29
MS(between)=(302.29)*(5) = 1511.45
df(groups) = 3−1 = 2
SS(group) = (1511.45)*2 = 3022.9

STEP7:
Test statistic and critical value:
F = 1511.45/155.07 = 9.75
Fcritical(2,12 ) = 3.89
decision : reject null hypothesis(H0)
    
STEP8:
source 	   SS 	    df 	      MS 	     F
group 	  3022.9 	 2 	   1511.45 	     9.75
error 	  1860.8 	12 	    155.07 	
total 	  4883.7

Effect size:
n*2 =3022.9/4883.7 = 0.62
F(2, 12) = 9.75, p <0.05, n*2 = 0.62

# %%
TASK 3.Calculate F Test for given 10, 20, 30, 40, 50 and 5,10,15, 20, 25.

SOLUTION :
STEP1: Calculate Variance of first set:
For 10, 20, 30, 40, 50:
Total Inputs (N) = (10,20,30,40,50)
Total Inputs (N) = 5
Mean (xm) = (x1+x1+x2...xn)/N
Mean (xm) = 150/5
Means(xm) = 30
SD = sqrt(1/(N-1)*((x1-xm)2+(x2-xm)2+..+(xn-xm)2))
   = sqrt(1/(5-1)((10-30)2+(20-30)2+(30-30)2+(40-30)2+(50-30)2))
   = sqrt(1/4((-20)2+(-10)2+(0)2+(10)2+(20)2))
   = sqrt(1/4((400)+(100)+(0)+(100)+(400)))
   = sqrt(250)
   = 15.8114
Variance = SD2
Variance = 15.81142
Variance = 250

STEP2: Calculate Variance of second set:
For 5, 10,15,20,25:
Total Inputs(N) = (5,10,15,20,25)
Total Inputs(N) = 5
Mean (xm) = (x1+x2+x3...xN)/N
Mean (xm) = 75/5
Means(xm) = 15
SD = sqrt(1/(N-1)*((x1-xm)2+(x2-xm)2+..+(xn-xm)2))
   = sqrt(1/(5-1)((5-15)2+(10-15)2+(15-15)2+(20-15)2+(25-15)2))
   = sqrt(1/4((-10)2+(-5)2+(0)2+(5)2+(10)2))
   = sqrt(1/4((100)+(25)+(0)+(25)+(100)))
   = sqrt(62.5)
   = 7.9057
Variance = SD2
Variance = 7.90572
Variance = 62.5

STEP3: Calculating F Test
F Test = (variance of 10, 20,30,40,50) / (variance of 5, 10, 15, 20, 25)
= 250/62.5
= 4
